# %%
import cv2
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.callbacks import Callback, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
import tensorflow as tf
from tqdm import tqdm
# Out:
# 2.16.1
# GPU not available :()

# %%
def build_model(pretrained):
    model = Sequential([
        pretrained,
        layers.GlobalAveragePooling2D(),
        layers.Dense(1, activation='sigmoid')
    ])
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(),
        metrics=['accuracy']
    )
    
    return model

# %% [markdown]
# # Generator

# %%
base_path = '../real_vs_fake/real-vs-fake/'
image_gen = ImageDataGenerator(rescale=1./255.,
                               rotation_range=20,
                               #shear_range=0.2,
                               #zoom_range=0.2,
                               horizontal_flip=True)

train_flow = image_gen.flow_from_directory(
    base_path + 'train/',
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)
# Out:
# Found 100000 images belonging to 2 classes.

# %%
image_gen1 = ImageDataGenerator(rescale=1./255.)

valid_flow = image_gen1.flow_from_directory(
    base_path + 'valid/',
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)
# Out:
# Found 20000 images belonging to 2 classes.

# %% [markdown]
# # Train Model DenseNet Augmented Data

# %%
densenet = DenseNet121(
    weights=None,
    include_top=False,
    input_shape=(224,224,3)
)
model = build_model(densenet)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet121 (Functional)        │ ?                      │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ ?                      │   0 (unbuilt) │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,037,504 (26.85 MB)
#  Trainable params: 6,953,856 (26.53 MB)
#  Non-trainable params: 83,648 (326.75 KB)

# %%
train_steps = 100000//64
valid_steps = 20000//64

history = model.fit(
    train_flow,
    epochs = 5,
    steps_per_epoch= train_steps,
    validation_data= valid_flow,
    validation_steps= valid_steps
)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\internal\containers.py:502, in MessageMap.__getitem__(self, key)
#     501 try:
# --> 502   return self._values[key]
#     503 except KeyError:
#
# KeyError: 'value'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 4
#       1 train_steps = 100000//64
#       2 valid_steps = 20000//64
# ----> 4 history = model.fit(
#       5     train_flow,
#       6     epochs = 5,
#       7     steps_per_epoch= train_steps,
#       8     validation_data= valid_flow,
#       9     validation_steps= valid_steps
#      10 )
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in error_handler(*args, **kwargs)
#     112 if arg.name in bound_signature.arguments:
#     113     value = tf.nest.map_structure(
#     114         format_argument_value,
#     115         bound_signature.arguments[arg.name],
#     116     )
# --> 117 else:
#     118     value = arg.default
#     119 arguments_context.append(f"  • {arg.name}={value}")
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:314, in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in __call__(self, *args, **kwds)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:889, in _call(self, *args, **kwds)
#     887   initializers = []
#     888   self._initialize(args, kwds, add_initializers_to=initializers)
# --> 889 finally:
#     890   # At this point we know that the initialization is complete (or less
#     891   # interestingly an exception was raised) so we no longer need a lock.
#     892   self._lock.release()
#     894 if self._created_variables:
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:696, in _initialize(self, args, kwds, add_initializers_to)
#     690 self._variable_creation_config = self._generate_scoped_tracing_options(
#     691     variable_capturing_scope,
#     692     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     693 )
#     694 # Force the definition of the function for these arguments
#     695 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
# --> 696     args, kwds, self._variable_creation_config
#     697 )
#     699 def invalid_creator_scope(*unused_args, **unused_kwds):
#     700   """Disables variable creation."""
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\framework\func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:599, in wrapped_fn(*args, **kwds)
#     597 with OptionalXlaContext(compile_with_xla):
#     598   out = weak_wrapped_fn().__wrapped__(*args, **kwds)
# --> 599 return out
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:339, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337 if is_autograph_artifact(f):
#     338   logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339   return _call_unconverted(f, args, kwargs, options)
#     341 # If this is a partial, unwrap it and redo all the checks.
#     342 if isinstance(f, functools.partial):
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:117, in one_step_on_iterator(iterator)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1673, in run(***failed resolving arguments***)
#    1670 del options
#    1672 if not isinstance(args, (list, tuple)):
# -> 1673   raise ValueError(
#    1674       "positional args must be a list or tuple, got {}".format(type(args)))
#    1676 with self.scope():
#    1677   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1678   # applied when the caller is also in Eager mode.
#    1679   fn = autograph.tf_convert(
#    1680       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3263, in call_for_each_replica(self, fn, args, kwargs)
#    3223 def call_for_each_replica(self, fn, args=(), kwargs=None):
#    3224   """Run `fn` once per replica.
#    3225
#    3226   `fn` may call `tf.get_replica_context()` to access methods such as
#    3227   `replica_id_in_sync_group` and `merge_call()`.
#    3228
#    3229   `merge_call()` is used to communicate between the replicas and
#    3230   re-enter the cross-replica context. All replicas pause their execution
#    3231   having encountered a `merge_call()` call. After that the
#    3232   `merge_fn`-function is executed. Its results are then unwrapped and
#    3233   given back to each replica call. After that execution resumes until
#    3234   `fn` is complete or encounters another `merge_call()`.  Example:
#    3235
#    3236   ```python
#    3237   # Called once in "cross-replica" context.
#    3238   def merge_fn(distribution, three_plus_replica_id):
#    3239     # sum the values across replicas
#    3240     return sum(distribution.experimental_local_results(three_plus_replica_id))
#    3241
#    3242   # Called once per replica in `distribution`, in a "replica" context.
#    3243   def fn(three):
#    3244     replica_ctx = tf.get_replica_context()
#    3245     v = three + replica_ctx.replica_id_in_sync_group
#    3246     # Computes the sum of the `v` values across all replicas.
#    3247     s = replica_ctx.merge_call(merge_fn, args=(v,))
#    3248     return s + v
#    3249
#    3250   with distribution.scope():
#    3251     # in "cross-replica" context
#    3252     ...
#    3253     merged_results = distribution.run(fn, args=[3])
#    3254     # merged_results has the values from every replica execution of `fn`.
#    3255     # This statement prints a list:
#    3256     print(distribution.experimental_local_results(merged_results))
#    3257   ```
#    3258
#    3259   Args:
#    3260     fn: function to run (will be run once per replica).
#    3261     args: Tuple or list with positional arguments for `fn`.
#    3262     kwargs: Dict with keyword arguments for `fn`.
# -> 3263
#    3264   Returns:
#    3265     Merged return value of `fn` across all replicas.
#    3266   """
#    3267   _require_cross_replica_or_default_context_extended(self)
#    3268   if kwargs is None:
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4061, in _call_for_each_replica(self, fn, args, kwargs)
#    4058   vars_nested = nest.pack_sequence_as(numpy_input, vars_flat)
#    4059   return dataset_ops.Dataset.from_tensor_slices(vars_nested)
# -> 4061 def _broadcast_to(self, tensor, destinations):
#    4062   if destinations is None:
#    4063     return tensor
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in __call__(self, *args, **kwds)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:906, in _call(self, *args, **kwds)
#     901     pass  # Fall through to cond-based initialization.
#     902   else:
#     903     # Lifting succeeded, so variables are initialized and we can run the
#     904     # no_variable_creation function.
#     905     return tracing_compilation.call_function(
# --> 906         args, kwds, self._no_variable_creation_config
#     907     )
#     908 else:
#     909   bound_args = self._concrete_variable_creation_fn.function_type.bind(
#     910       *args, **kwds
#     911   )
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1334, in _call_flat(self, tensor_inputs, captured_inputs)
#    1330   flat_outputs = forward_function.call_flat(*args_with_tangents)
#    1331 else:
#    1332   with default_graph._override_gradient_function(  # pylint: disable=protected-access
#    1333       {"PartitionedCall": self._get_gradient_function(),
# -> 1334        "StatefulPartitionedCall": self._get_gradient_function()}):
#    1335     flat_outputs = forward_function.call_flat(*args_with_tangents)
#    1336 forward_backward.record(flat_outputs)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:233, in AtomicFunction.call_flat(self, *args)
#     219 def call_flat(self, *args: core.Tensor) -> Sequence[core.Tensor]:
#     220   """Calls with flat tensor inputs and returns flat tensor outputs.
#     221
#     222   Args:
#    (...)
#     231       available to be called because it has been garbage collected.
#     232   """
# --> 233   expected_len = len(self.cached_definition.signature.input_arg)
#     234   if len(args) != expected_len:
#     235     raise ValueError(
#     236         f"Signature specifies {expected_len} arguments, got: {len(args)}."
#     237         f" Expected inputs: {self.cached_definition.signature.input_arg}."
#     238         f" Received inputs: {args}."
#     239         f" Function Type: {self.function_type!r}"
#     240     )
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:189, in AtomicFunction.cached_definition(self)
#     187 """Cached FunctionDef (not guaranteed to be fresh)."""
#     188 if self._cached_definition is None:
# --> 189   self._cached_definition = self.definition
#     191 return self._cached_definition
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:144, in AtomicFunction.definition(self)
#     141 @property
#     142 def definition(self) -> function_pb2.FunctionDef:
#     143   """Current FunctionDef in the Runtime."""
# --> 144   return self._bound_context.get_function_def(self.name)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\context.py:1409, in get_function_def(self, name)
#    1402 def get_graph_debug_info(self, name):
#    1403   """Get GraphDebugInfo associated with a function from the context.
#    1404
#    1405   Args:
#    1406     name: function signature name.
#    1407
#    1408   Returns:
# -> 1409     The requested GraphDebugInfo.
#    1410
#    1411   Raises:
#    1412     tf.errors.NotFoundError: if name is not the name of a registered function.
#    1413   """
#    1414   with c_api_util.tf_buffer() as buffer_:
#    1415     pywrap_tfe.TFE_ContextGetGraphDebugInfo(self._handle, name, buffer_)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\message.py:202, in Message.ParseFromString(self, serialized)
#     194 """Parse serialized protocol buffer data into this message.
#     195
#     196 Like :func:`MergeFromString()`, except we clear the object first.
#    (...)
#     199   message.DecodeError if the input cannot be parsed.
#     200 """
#     201 self.Clear()
# --> 202 return self.MergeFromString(serialized)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\internal\python_message.py:1128, in _AddMergeFromStringMethod.<locals>.MergeFromString(self, serialized)
#    1126 length = len(serialized)
#    1127 try:
# -> 1128   if self._InternalParse(serialized, 0, length) != length:
#    1129     # The only reason _InternalParse would return early is if it
#    1130     # encountered an end-group tag.
#    1131     raise message_mod.DecodeError('Unexpected end-group tag.')
#    1132 except (IndexError, TypeError):
#    1133   # Now ord(buf[p:p+1]) == ord('') gets TypeError.
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\internal\python_message.py:1195, in _AddMergeFromStringMethod.<locals>.InternalParse(self, buffer, pos, end)
#    1193   pos = new_pos
#    1194 else:
# -> 1195   pos = field_decoder(buffer, new_pos, end, self, field_dict)
#    1196   if field_desc:
#    1197     self._UpdateOneofState(field_desc)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\internal\decoder.py:705, in MessageDecoder.<locals>.DecodeRepeatedField(buffer, pos, end, message, field_dict)
#     703   raise _DecodeError('Truncated message.')
#     704 # Read sub-message.
# --> 705 if value.add()._InternalParse(buffer, pos, new_pos) != new_pos:
#     706   # The only reason _InternalParse would return early is if it
#     707   # encountered an end-group tag.
#     708   raise _DecodeError('Unexpected end-group tag.')
#     709 # Predict that the next tag is another copy of the same repeated field.
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\internal\python_message.py:1195, in _AddMergeFromStringMethod.<locals>.InternalParse(self, buffer, pos, end)
#    1193   pos = new_pos
#    1194 else:
# -> 1195   pos = field_decoder(buffer, new_pos, end, self, field_dict)
#    1196   if field_desc:
#    1197     self._UpdateOneofState(field_desc)
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\internal\decoder.py:866, in MapDecoder.<locals>.DecodeMap(buffer, pos, end, message, field_dict)
#     863   raise _DecodeError('Unexpected end-group tag.')
#     865 if is_message_map:
# --> 866   value[submsg.key].CopyFrom(submsg.value)
#     867 else:
#     868   value[submsg.key] = submsg.value
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\internal\containers.py:504, in MessageMap.__getitem__(self, key)
#     502   return self._values[key]
#     503 except KeyError:
# --> 504   new_element = self._message_descriptor._concrete_class()
#     505   new_element._SetListener(self._message_listener)
#     506   self._values[key] = new_element
#
# File c:\Users\kanko\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\internal\python_message.py:513, in _AddInitMethod.<locals>.init(self, **kwargs)
#     511 self._unknown_field_set = None      # pylint: disable=protected-access
#     512 self._is_present_in_parent = False
# --> 513 self._listener = message_listener_mod.NullMessageListener()
#     514 self._listener_for_children = _Listener(self)
#     515 for field_name, field_value in kwargs.items():
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Import TensorFlow into jupyter notebook
#       2 import tensorflow as tf1
# ----> 3 print(tf1.version)
#
# AttributeError: module 'tensorflow' has no attribute 'version'

# %% [markdown]
# # Evaluation

# %%
#model.save('completed_augmented_trained_model.h5')

# %%
"""
Plot the training and validation loss
epochs - list of epoch numbers
loss - training loss for each epoch
val_loss - validation loss for each epoch
"""
def plot_loss(epochs, loss, val_loss):
    plt.plot(epochs, loss, 'bo', label='Training Loss')
    plt.plot(epochs, val_loss, 'orange', label = 'Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()
"""
Plot the training and validation accuracy
epochs - list of epoch numbers
acc - training accuracy for each epoch
val_acc - validation accuracy for each epoch
"""
def plot_accuracy(epochs, acc, val_acc):
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'orange', label = 'Validation accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plot_loss(range(1, len(loss) + 1), loss, val_loss)
plot_accuracy(range(1, len(loss) + 1), acc, val_acc)

# %%
test_flow = image_gen1.flow_from_directory(
    base_path + 'test/',
    target_size=(224, 224),
    batch_size=1,
    shuffle = False,
    class_mode='binary'
)
y_pred=model.predict(test_flow)
y_test = test_flow.classes
# Out:
# Found 20000 images belonging to 2 classes.

# %%
print("ROC AUC Score:", metrics.roc_auc_score(y_test, y_pred))
print("AP Score:", metrics.average_precision_score(y_test, y_pred))
print()
print(metrics.classification_report(y_test, y_pred > 0.5))
# Out:
# ROC AUC Score: 0.9754987100000001
# AP Score: 0.9752373964211345
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92     10000
#            1       0.91      0.93      0.92     10000
#
#     accuracy                           0.92     20000
#    macro avg       0.92      0.92      0.92     20000
# weighted avg       0.92      0.92      0.92     20000
